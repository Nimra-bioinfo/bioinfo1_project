# %% [markdown]
# # Comparative Target Analysis Pipeline: Automated Multi-Species Serotonin 5-HT2A Sequence analyzer
#
# An exploratory bioinformatics project comparing the evolutionary conservation of the Serotonin 5-HT2A receptor across species (**Human, Mouse, and Zebrafish**).
#
# ##  Key Discoveries
# * **High Evolutionary Conservation:** Human and Mouse 5-HT2A receptors share a **91.51% sequence similarity** despite ~80+ million years of evolutionary separation.
# * **Length Consistency**: Both Human and Mouse receptors consist of **471 amino acids**, while Zebrafish consists of **466 amino acids**.
#
# ##  Tools & Technologies Used
# * **Python 3**
# * **Biopython** (Data parsing & sequence analysis)
# * **Requests** (Fetching live UniProt database entries)
# * **Matplotlib** (Data visualization)
#
# ##  Dataset Sources
# Data fetched directly from the **UniProt Knowledgebase**:
# * Human: `P28223`
# * Mouse: `P35363`
# * Zebrafish: `Q98894`
#
# ##  Real-World Applications & Impact
# * **Preclinical Target Validation:** Helps computational biologists quickly verify if animal models (like mouse or zebrafish) maintain the target protein structure before investing in costly lab experiments.
# * **Drug Discovery Workflows:** Serves as an automated data-ingestion module that can be integrated into downstream machine learning pipelines for virtual screening and ligand docking.

# %% [markdown]
# # project purpose, Research Questions & Critical Analysis
#
# ##  Project Overview
# This document outlines the analytical thought process, data processing choices, and biological database considerations used in this bioinformatics project (`bioinfo1_project`).
#
# ---
#
# ##  1. Key Research Questions & Mindset
#
# Before executing the computational workflow, several key research and technical questions were addressed:
#
# > **Q1: Why was this project conducted, and what is its real-world practical value?**
# > **Answer:** > The primary objective of this project is to perform a comparative bioinformatics analysis on the **Serotonin 5-HT2A Receptor** across three key biological species (*Homo sapiens*, *Mus musculus*, and *Danio rerio*).
#
# > In modern biomedical research, testing new drugs directly on humans is ethically and practically impossible during the early stages. Scientists rely heavily on **model organisms** like mice and zebrafish. By analyzing and comparing the amino acid sequences of this receptor, we can determine how structurally conserved the target protein is across species, validating whether these animals serve as accurate biological models for human neurological diseases.
#
# > **Q2: How does this pipeline help in Pharmaceutical Drug Discovery (Pharmacology)?**
# > * **Answer:** The 5-HT2A receptor is the primary target for **atypical antipsychotics** (used to treat schizophrenia and depression) as well as **psychedelic therapeutics**. Knowing that the Human and Mouse receptors have the exact same length (471 amino acids) helps pharmacologists predict whether a drug tested on a mouse model will bind similarly to the human receptor binding pocket.
#
# > **Q3: What is the benefit of automating sequence retrieval instead of doing it manually?**
# > * **Answer:** Manual retrieval of FASTA files from web databases is slow, prone to human error, and hard to scale. By engineering an automated Python pipeline using the UniProt REST API:
# >   1. **Scalability:** The pipeline can be scaled instantly from 3 species to 300+ species by simply modifying a single dictionary.
# >   2. **Reproducibility:** Any researcher globally can run the exact same notebook and dynamically pull the latest, most up-to-date reference sequences directly into memory.
#
# * **Q2: Why select specific bioinformatics tools and libraries (Pandas, Matplotlib)?**
#   * **Rationale:** Pandas allows efficient structured handling of genomic data frames, while Matplotlib offers customized visualization of key sequence metrics like GC content and sequence length distributions.
#
#
# ##  2. Methodological Decisions & Challenges
#
# ### A. Data Preprocessing & Cleaning
# * **Challenge:** Raw sequence data often contains noise, variable sequence lengths, and unnecessary terminal logs.
# * **Solution:** Automated scripts were used to parse and clean sequence outputs before calculating genomic statistics.
#
# ### B. Customization vs. Automated Pipelines
# * To maintain authentic scientific research standards:
#   1. Standard generic variables (e.g., `data`, `df`) were replaced with context-aware labels (e.g., `gene_df`, `seq_metrics`).
#   2. Data distributions (e.g., GC content) were plotted using refined parameters for biological clarity.
#
# ##  Conclusion & Future Directions
# This project demonstrates an end-to-end bioinformatics workflow combining raw sequence analysis with clear documentation. Future iterations will incorporate direct API fetches from NCBI/UniProt to automate real-time genomic updates.
